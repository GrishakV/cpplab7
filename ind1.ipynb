# %%
import numpy as np
import pandas as pd

# %%
acct = pd.Series([0, 0, 0], ['расчетный счет плательщика', 'расчетный счет получателя', 'перечисляемая сумма в руб.'])
acct
# Out:
# расчетный счет плательщика    0
# расчетный счет получателя     0
# перечисляемая сумма в руб.    0
# dtype: int64

# %%
a = input('>>')
# Out:
# >>555

# %%
a
# Out:
# '555'
